# %%
import pandas as pd
dust = pd.read_excel('C:/Users/user/Desktop/dust.xlsx')
dust.head()
# Out:
#               날짜  아황산가스  일산화탄소     오존  이산화질소  PM10  PM2.5
# 0  2021-01-01 01  0.004    0.4  0.021  0.018   NaN   12.0
# 1  2021-01-01 02  0.004    0.4  0.019  0.020  20.0   13.0
# 2  2021-01-01 03  0.004    0.5  0.017  0.023  23.0   13.0
# 3  2021-01-01 04  0.004    0.5  0.015  0.024  17.0   12.0
# 4  2021-01-01 05  0.004    0.5  0.010  0.026   NaN   14.0

# %%
dust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      744 non-null    object
#  1   아황산가스   740 non-null    float64
#  2   일산화탄소   740 non-null    float64
#  3   오존      740 non-null    float64
#  4   이산화질소   740 non-null    float64
#  5   PM10    725 non-null    float64
#  6   PM2.5   739 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 40.8+ KB

# %%
dust.describe()
# Out:
#             아황산가스       일산화탄소          오존       이산화질소        PM10       PM2.5
# count  740.000000  740.000000  740.000000  740.000000  725.000000  739.000000
# mean     0.003654    0.563243    0.014154    0.030422   33.325517   21.833559
# std      0.000628    0.164593    0.010689    0.014664   19.930029   12.222892
# min      0.002000    0.300000    0.001000    0.006000    3.000000    3.000000
# 25%      0.003000    0.400000    0.003000    0.017000   20.000000   13.000000
# 50%      0.004000    0.500000    0.014000    0.030000   29.000000   19.000000
# 75%      0.004000    0.700000    0.024000    0.043000   43.000000   29.000000
# max      0.006000    1.200000    0.037000    0.063000  163.000000   72.000000

# %%
dust.columns = ['date','so2','co','o3','no2','PM10','PM2.5']
dust.head()
# Out:
#             date    so2   co     o3    no2  PM10  PM2.5
# 0  2021-01-01 01  0.004  0.4  0.021  0.018   NaN   12.0
# 1  2021-01-01 02  0.004  0.4  0.019  0.020  20.0   13.0
# 2  2021-01-01 03  0.004  0.5  0.017  0.023  23.0   13.0
# 3  2021-01-01 04  0.004  0.5  0.015  0.024  17.0   12.0
# 4  2021-01-01 05  0.004  0.5  0.010  0.026   NaN   14.0

# %%
dust['date']=dust['date'].str[:11]
dust.head()
# Out:
#           date    so2   co     o3    no2  PM10  PM2.5
# 0  2021-01-01   0.004  0.4  0.021  0.018   NaN   12.0
# 1  2021-01-01   0.004  0.4  0.019  0.020  20.0   13.0
# 2  2021-01-01   0.004  0.5  0.017  0.023  23.0   13.0
# 3  2021-01-01   0.004  0.5  0.015  0.024  17.0   12.0
# 4  2021-01-01   0.004  0.5  0.010  0.026   NaN   14.0

# %%
dust['date'] = pd.to_datetime(dust['date'])
dust.dtypes
# Out:
# date     datetime64[ns]
# so2             float64
# co              float64
# o3              float64
# no2             float64
# PM10            float64
# PM2.5           float64
# dtype: object

# %%
dust['year'] = dust['date'].dt.year
dust['month'] = dust['date'].dt.month
dust['day'] = dust['date'].dt.day
dust
# Out:
#           date    so2   co     o3    no2  PM10  PM2.5  year  month  day
# 0   2021-01-01  0.004  0.4  0.021  0.018   NaN   12.0  2021      1    1
# 1   2021-01-01  0.004  0.4  0.019  0.020  20.0   13.0  2021      1    1
# 2   2021-01-01  0.004  0.5  0.017  0.023  23.0   13.0  2021      1    1
# 3   2021-01-01  0.004  0.5  0.015  0.024  17.0   12.0  2021      1    1
# 4   2021-01-01  0.004  0.5  0.010  0.026   NaN   14.0  2021      1    1
# ..         ...    ...  ...    ...    ...   ...    ...   ...    ...  ...
# 739 2021-01-31  0.004  0.7  0.002  0.057  45.0   23.0  2021      1   31
# 740 2021-01-31  0.004  0.8  0.001  0.059  48.0   27.0  2021      1   31
# 741 2021-01-31  0.003  1.0  0.001  0.061  46.0   26.0  2021      1   31
# 742 2021-01-31  0.003  0.6  0.006  0.049  45.0   24.0  2021      1   31
# 743 2021-01-31  0.003  0.7  0.005  0.054  40.0   19.0  2021      1   31
#
# [744 rows x 10 columns]

# %%
dust = dust[['date', 'year', 'month', 'day', 'so2', 'co', 'o3','no2', 'PM10', 'PM2.5']]
dust.head()
# Out:
#         date  year  month  day    so2   co     o3    no2  PM10  PM2.5
# 0 2021-01-01  2021      1    1  0.004  0.4  0.021  0.018   NaN   12.0
# 1 2021-01-01  2021      1    1  0.004  0.4  0.019  0.020  20.0   13.0
# 2 2021-01-01  2021      1    1  0.004  0.5  0.017  0.023  23.0   13.0
# 3 2021-01-01  2021      1    1  0.004  0.5  0.015  0.024  17.0   12.0
# 4 2021-01-01  2021      1    1  0.004  0.5  0.010  0.026   NaN   14.0

# %%
#결측치 확인
dust.isnull().sum()
# Out:
# date      0
# year      0
# month     0
# day       0
# so2       4
# co        4
# o3        4
# no2       4
# PM10     19
# PM2.5     5
# dtype: int64

# %%
dust=dust.fillna(method='ffill')
dust.isnull().sum()
dust
# Out:
#           date  year  month  day    so2   co     o3    no2  PM10  PM2.5
# 0   2021-01-01  2021      1    1  0.004  0.4  0.021  0.018   NaN   12.0
# 1   2021-01-01  2021      1    1  0.004  0.4  0.019  0.020  20.0   13.0
# 2   2021-01-01  2021      1    1  0.004  0.5  0.017  0.023  23.0   13.0
# 3   2021-01-01  2021      1    1  0.004  0.5  0.015  0.024  17.0   12.0
# 4   2021-01-01  2021      1    1  0.004  0.5  0.010  0.026  17.0   14.0
# ..         ...   ...    ...  ...    ...  ...    ...    ...   ...    ...
# 739 2021-01-31  2021      1   31  0.004  0.7  0.002  0.057  45.0   23.0
# 740 2021-01-31  2021      1   31  0.004  0.8  0.001  0.059  48.0   27.0
# 741 2021-01-31  2021      1   31  0.003  1.0  0.001  0.061  46.0   26.0
# 742 2021-01-31  2021      1   31  0.003  0.6  0.006  0.049  45.0   24.0
# 743 2021-01-31  2021      1   31  0.003  0.7  0.005  0.054  40.0   19.0
#
# [744 rows x 10 columns]

# %%
dust.fillna(20, inplace=True)
dust.head()
# Out:
#         date  year  month  day    so2   co     o3    no2  PM10  PM2.5
# 0 2021-01-01  2021      1    1  0.004  0.4  0.021  0.018  20.0   12.0
# 1 2021-01-01  2021      1    1  0.004  0.4  0.019  0.020  20.0   13.0
# 2 2021-01-01  2021      1    1  0.004  0.5  0.017  0.023  23.0   13.0
# 3 2021-01-01  2021      1    1  0.004  0.5  0.015  0.024  17.0   12.0
# 4 2021-01-01  2021      1    1  0.004  0.5  0.010  0.026  17.0   14.0

# %%
dust.isnull().sum()
# Out:
# date     0
# year     0
# month    0
# day      0
# so2      0
# co       0
# o3       0
# no2      0
# PM10     0
# PM2.5    0
# dtype: int64

# %% [markdown]
# # 날씨데이터

# %%
weather = pd.read_excel('C:/Users/user/Desktop/weather.xlsx')

# %%
weather.head()
# Out:
#     지점 지점명                  일시  기온(°C)  풍속(m/s)  강수량(mm)  습도(%)
# 0  400  강남 2021-01-01 01:00:00    -7.2      0.6      0.0   57.5
# 1  400  강남 2021-01-01 02:00:00    -7.6      0.7      0.0   57.5
# 2  400  강남 2021-01-01 03:00:00    -8.2      0.6      0.0   62.0
# 3  400  강남 2021-01-01 04:00:00    -8.1      0.5      0.0   60.5
# 4  400  강남 2021-01-01 05:00:00    -8.7      1.3      0.0   66.4

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 743 entries, 0 to 742
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지점       743 non-null    int64
#  1   지점명      743 non-null    object
#  2   일시       743 non-null    datetime64[ns]
#  3   기온(°C)   743 non-null    float64
#  4   풍속(m/s)  743 non-null    float64
#  5   강수량(mm)  743 non-null    float64
#  6   습도(%)    743 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 40.8+ KB

# %%
weather.drop('지점', axis=1, inplace=True)
weather.drop('지점명', axis=1, inplace=True)
weather.head()
# Out:
#                    일시  기온(°C)  풍속(m/s)  강수량(mm)  습도(%)
# 0 2021-01-01 01:00:00    -7.2      0.6      0.0   57.5
# 1 2021-01-01 02:00:00    -7.6      0.7      0.0   57.5
# 2 2021-01-01 03:00:00    -8.2      0.6      0.0   62.0
# 3 2021-01-01 04:00:00    -8.1      0.5      0.0   60.5
# 4 2021-01-01 05:00:00    -8.7      1.3      0.0   66.4

# %%
weather.columns = ['date','temp','wind','rain','humid']

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 743 entries, 0 to 742
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    743 non-null    datetime64[ns]
#  1   temp    743 non-null    float64
#  2   wind    743 non-null    float64
#  3   rain    743 non-null    float64
#  4   humid   743 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 29.2 KB

# %%
weather
# Out:
#                    date  temp  wind  rain  humid
# 0   2021-01-01 01:00:00  -7.2   0.6   0.0   57.5
# 1   2021-01-01 02:00:00  -7.6   0.7   0.0   57.5
# 2   2021-01-01 03:00:00  -8.2   0.6   0.0   62.0
# 3   2021-01-01 04:00:00  -8.1   0.5   0.0   60.5
# 4   2021-01-01 05:00:00  -8.7   1.3   0.0   66.4
# ..                  ...   ...   ...   ...    ...
# 738 2021-01-31 19:00:00   7.4   0.6   0.0   51.0
# 739 2021-01-31 20:00:00   6.5   1.0   0.0   59.4
# 740 2021-01-31 21:00:00   7.7   1.0   0.0   60.3
# 741 2021-01-31 22:00:00   6.8   0.6   0.0   63.7
# 742 2021-01-31 23:00:00   7.1   1.0   0.0   60.2
#
# [743 rows x 5 columns]

# %%
weather['date'] = pd.to_datetime(weather['date']).dt.date

# %%
weather
# Out:
#            date  temp  wind  rain  humid
# 0    2021-01-01  -7.2   0.6   0.0   57.5
# 1    2021-01-01  -7.6   0.7   0.0   57.5
# 2    2021-01-01  -8.2   0.6   0.0   62.0
# 3    2021-01-01  -8.1   0.5   0.0   60.5
# 4    2021-01-01  -8.7   1.3   0.0   66.4
# ..          ...   ...   ...   ...    ...
# 738  2021-01-31   7.4   0.6   0.0   51.0
# 739  2021-01-31   6.5   1.0   0.0   59.4
# 740  2021-01-31   7.7   1.0   0.0   60.3
# 741  2021-01-31   6.8   0.6   0.0   63.7
# 742  2021-01-31   7.1   1.0   0.0   60.2
#
# [743 rows x 5 columns]

# %%
weather['date'] = pd.to_datetime(weather['date'])

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 743 entries, 0 to 742
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    743 non-null    datetime64[ns]
#  1   temp    743 non-null    float64
#  2   wind    743 non-null    float64
#  3   rain    743 non-null    float64
#  4   humid   743 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 29.2 KB

# %%
weather['rain'] = weather['rain'].replace([0], 0.01)

# %%
weather['rain'].value_counts()
# Out:
# 0.01    720
# 0.50      9
# 1.00      7
# 1.50      3
# 2.50      2
# 2.00      2
# Name: rain, dtype: int64

# %% [markdown]
# # 데이터병합

# %%
dust.shape
# Out:
# (744, 10)

# %%
weather.shape
# Out:
# (743, 5)

# %%
dust.drop(index=743, inplace=True)

# %%
dust.shape
# Out:
# (743, 10)

# %%
df = pd.merge(dust, weather, on='date')

# %%
df
# Out:
#             date  year  month  day    so2   co     o3    no2  PM10  PM2.5  \
# 0     2021-01-01  2021      1    1  0.004  0.4  0.021  0.018  20.0   12.0
# 1     2021-01-01  2021      1    1  0.004  0.4  0.021  0.018  20.0   12.0
# 2     2021-01-01  2021      1    1  0.004  0.4  0.021  0.018  20.0   12.0
# 3     2021-01-01  2021      1    1  0.004  0.4  0.021  0.018  20.0   12.0
# 4     2021-01-01  2021      1    1  0.004  0.4  0.021  0.018  20.0   12.0
# ...          ...   ...    ...  ...    ...  ...    ...    ...   ...    ...
# 17803 2021-01-31  2021      1   31  0.003  0.6  0.006  0.049  45.0   24.0
# 17804 2021-01-31  2021      1   31  0.003  0.6  0.006  0.049  45.0   24.0
# 17805 2021-01-31  2021      1   31  0.003  0.6  0.006  0.049  45.0   24.0
# 17806 2021-01-31  2021      1   31  0.003  0.6  0.006  0.049  45.0   24.0
# 17807 2021-01-31  2021      1   31  0.003  0.6  0.006  0.049  45.0   24.0
#
#        temp  wind  rain  humid
# 0      -7.2   0.6  0.01   57.5
# 1      -7.6   0.7  0.01   57.5
# 2      -8.2   0.6  0.01   62.0
# 3      -8.1   0.5  0.01   60.5
# 4      -8.7   1.3  0.01   66.4
# ...     ...   ...   ...    ...
# 17803   7.4   0.6  0.01   51.0
# 17804   6.5   1.0  0.01   59.4
# 17805   7.7   1.0  0.01   60.3
# 17806   6.8   0.6  0.01   63.7
# 17807   7.1   1.0  0.01   60.2
#
# [17808 rows x 14 columns]

# %%
df.corr()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_11168\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#        year  month       day       so2        co        o3       no2  \
# year    NaN    NaN       NaN       NaN       NaN       NaN       NaN
# month   NaN    NaN       NaN       NaN       NaN       NaN       NaN
# day     NaN    NaN  1.000000 -0.318239  0.226099 -0.118081  0.206333
# so2     NaN    NaN -0.318239  1.000000  0.141117 -0.068687  0.085989
# co      NaN    NaN  0.226099  0.141117  1.000000 -0.756706  0.841594
# o3      NaN    NaN -0.118081 -0.068687 -0.756706  1.000000 -0.924362
# no2     NaN    NaN  0.206333  0.085989  0.841594 -0.924362  1.000000
# PM10    NaN    NaN  0.016124  0.160874  0.529720 -0.348229  0.420554
# PM2.5   NaN    NaN  0.051036  0.147571  0.692664 -0.525078  0.566387
# temp    NaN    NaN  0.491312 -0.375131  0.318052 -0.203804  0.313188
# wind    NaN    NaN -0.074944  0.031460 -0.322431  0.355105 -0.403745
# rain    NaN    NaN  0.026688 -0.019907  0.077531 -0.096761  0.109930
# humid   NaN    NaN  0.176721 -0.096445  0.338083 -0.288327  0.315524
#
#            PM10     PM2.5      temp      wind      rain     humid
# year        NaN       NaN       NaN       NaN       NaN       NaN
# month       NaN       NaN       NaN       NaN       NaN       NaN
# day    0.016124  0.051036  0.491312 -0.074944  0.026688  0.176721
# so2    0.160874  0.147571 -0.375131  0.031460 -0.019907 -0.096445
# co     0.529720  0.692664  0.318052 -0.322431  0.077531  0.338083
# o3    -0.348229 -0.525078 -0.203804  0.355105 -0.096761 -0.288327
# no2    0.420554  0.566387  0.313188 -0.403745  0.109930  0.315524
# PM10   1.000000  0.825433  0.175430 -0.108474  0.026272  0.216753
# PM2.5  0.825433  1.000000  0.190698 -0.202018  0.069123  0.354713
# temp   0.175430  0.190698  1.000000 -0.211112  0.077652  0.213428
# wind  -0.108474 -0.202018 -0.211112  1.000000 -0.077998 -0.461900
# rain   0.026272  0.069123  0.077652 -0.077998  1.000000  0.284108
# humid  0.216753  0.354713  0.213428 -0.461900  0.284108  1.000000

# %%
corr = df.corr()
corr['PM10'].sort_values(ascending=False)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_11168\289289980.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# PM10     1.000000
# PM2.5    0.825433
# co       0.529720
# no2      0.420554
# humid    0.216753
# temp     0.175430
# so2      0.160874
# rain     0.026272
# day      0.016124
# wind    -0.108474
# o3      -0.348229
# year          NaN
# month         NaN
# Name: PM10, dtype: float64

# %%
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'date'}>,
#         <Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'month'}>,
#         <Axes: title={'center': 'day'}>],
#        [<Axes: title={'center': 'so2'}>, <Axes: title={'center': 'co'}>,
#         <Axes: title={'center': 'o3'}>, <Axes: title={'center': 'no2'}>],
#        [<Axes: title={'center': 'PM10'}>,
#         <Axes: title={'center': 'PM2.5'}>,
#         <Axes: title={'center': 'temp'}>,
#         <Axes: title={'center': 'wind'}>],
#        [<Axes: title={'center': 'rain'}>,
#         <Axes: title={'center': 'humid'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,10))
dayGraph = sns.barplot(x='day', y='PM10', data=df)
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data=corr, annot=True, fmt='.2f', cmap='hot')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,10))
x=df['temp']
y=df['PM10']
plt.plot(x, y, marker='o', linestyle='none', alpha=0.5)
plt.title('temp - pm10')
plt.xlabel('temp')
plt.ylabel('pm10')
plt.show()

# %%
plt.figure(figsize=(15,10))
x=df['PM10']
y=df['PM2.5']
plt.plot(x,y,marker='o',linestyle='none',color='red',alpha=0.5)

# %%
sns.pairplot(df)
